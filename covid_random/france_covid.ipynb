# %%
#Data is from https://www.data.gouv.fr/

# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt

# %%
url_data ='https://raw.githubusercontent.com/opencovid19-fr/data/master/data-sources/sante-publique-france/covid_hospit.csv'

# %%
covid_df = pd.read_csv(url_data,sep=';')

# %%
covid_df.head()
# Out:
#   dep  sexe        jour  hosp  rea  rad  dc
# 0  01     0  2020-03-18     2    0    1   0
# 1  01     1  2020-03-18     1    0    1   0
# 2  01     2  2020-03-18     1    0    0   0
# 3  02     0  2020-03-18    41   10   18  11
# 4  02     1  2020-03-18    19    4   11   6

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15759 entries, 0 to 15758
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   dep     15756 non-null  object
#  1   sexe    15759 non-null  int64
#  2   jour    15759 non-null  object
#  3   hosp    15759 non-null  int64
#  4   rea     15759 non-null  int64
#  5   rad     15759 non-null  int64
#  6   dc      15759 non-null  int64
# dtypes: int64(5), object(2)
# memory usage: 861.9+ KB

# %%
covid_df.plot(x = 'hosp', y = 'dc')

# %%
covid_df.pivot_table(index="hosp",values="dc")
# Out:
#                dc
# hosp
# 0        0.167203
# 1        0.136986
# 2        0.878505
# 3        1.018382
# 4        1.000000
# ...           ...
# 3209  1054.000000
# 3219   867.000000
# 3249   912.000000
# 3266   959.000000
# 3281  1003.000000
#
# [1218 rows x 1 columns]

# %%
covid_df.describe()
# Out:
#                sexe          hosp           rea           rad            dc
# count  15759.000000  15759.000000  15759.000000  15759.000000  15759.000000
# mean       1.000000    157.095945     30.720985    179.157815     58.134844
# std        0.816522    298.341586     62.907756    355.453549    125.768601
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000     19.000000      3.000000     16.000000      3.000000
# 50%        1.000000     53.000000     10.000000     54.000000     15.000000
# 75%        2.000000    142.000000     29.000000    173.000000     50.000000
# max        2.000000   3281.000000    855.000000   4659.000000   1562.000000

# %%
from pandas.plotting import andrews_curves

# %%
del covid_df['jour']

# %%
covid_df.head()
# Out:
#   dep  sexe  hosp  rea  rad  dc
# 0  01     0     2    0    1   0
# 1  01     1     1    0    1   0
# 2  01     2     1    0    0   0
# 3  02     0    41   10   18  11
# 4  02     1    19    4   11   6

# %%
plt.figure()
andrews_curves(covid_df, 'dep')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-23a64c31d6f8> in <module>
#       1 plt.figure()
# ----> 2 andrews_curves(covid_df, 'sexe')
#       3
#       4 plt.show()
#
# d:\matth\Documents\python_projects\covid-random\.venv\lib\site-packages\pandas\plotting\_misc.py in andrews_curves(frame, class_column, ax, samples, color, colormap, **kwargs)
#     245     """
#     246     plot_backend = _get_plot_backend("matplotlib")
# --> 247     return plot_backend.andrews_curves(
#     248         frame=frame,
#     249         class_column=class_column,
#
# d:\matth\Documents\python_projects\covid-random\.venv\lib\site-packages\pandas\plotting\_matplotlib\misc.py in andrews_curves(frame, class_column, ax, samples, color, colormap, **kwds)
#     243         row = df.iloc[i].values
#     244         f = function(row)
# --> 245         y = f(t)
# ...
