# %%
#Data is from https://www.data.gouv.fr/

# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt

# %%
url_data ='https://raw.githubusercontent.com/opencovid19-fr/data/master/data-sources/sante-publique-france/covid_hospit.csv'

# %%
covid_df = pd.read_csv(url_data,sep=';')

# %%
covid_df.head()
# Out:
#   dep  sexe        jour  hosp  rea  rad  dc
# 0  01     0  2020-03-18     2    0    1   0
# 1  01     1  2020-03-18     1    0    1   0
# 2  01     2  2020-03-18     1    0    0   0
# 3  02     0  2020-03-18    41   10   18  11
# 4  02     1  2020-03-18    19    4   11   6

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12426 entries, 0 to 12425
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   dep     12423 non-null  object
#  1   sexe    12426 non-null  int64
#  2   jour    12426 non-null  object
#  3   hosp    12426 non-null  int64
#  4   rea     12426 non-null  int64
#  5   rad     12426 non-null  int64
#  6   dc      12426 non-null  int64
# dtypes: int64(5), object(2)
# memory usage: 679.7+ KB

# %%
covid_df.plot(x = 'hosp', y = 'dc')

# %%
covid_df.pivot_table(index="hosp",values="dc")
# Out:
#                dc
# hosp
# 0        0.024823
# 1        0.104712
# 2        0.391061
# 3        0.336100
# 4        0.405000
# ...           ...
# 3209  1054.000000
# 3219   867.000000
# 3249   912.000000
# 3266   959.000000
# 3281  1003.000000
#
# [1104 rows x 1 columns]

# %%
covid_df.describe()
# Out:
#                sexe          hosp           rea           rad            dc
# count  12426.000000  12426.000000  12426.000000  12426.000000  12426.000000
# mean       1.000000    154.623934     32.588605    136.597698     46.053517
# std        0.816529    301.212243     66.434564    277.395525    104.349784
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000     18.000000      3.000000     11.000000      2.000000
# 50%        1.000000     50.000000     10.000000     40.000000     11.000000
# 75%        2.000000    140.000000     31.000000    130.000000     38.000000
# max        2.000000   3281.000000    855.000000   3735.000000   1387.000000
